# %%
from pyrogram import Client, filters
from dotenv import load_dotenv
import os

from llm_workflow.main_chat_workflow import MainChatWorkflow


load_dotenv()

main_wf = MainChatWorkflow()

# %%
thread_id = str(4)
result = main_wf.chat_to_ai('Яка погода завтра??', thread_id=thread_id)
# Out:
# /home/serhii/Desktop/projects/ai-twin/llm_workflow/core/common_agents/supervisor_agent.py:59: LangChainDeprecationWarning: The method `BaseChatOpenAI.bind_functions` was deprecated in langchain-openai 0.2.1 and will be removed in 0.3.0. Use :meth:`~langchain_openai.chat_models.base.ChatOpenAI.bind_tools` instead.
#   | llm.bind_functions(functions=[function_def], function_call="route")
# {'explanation': "To provide the most accurate weather forecast, we should first gather information about the user's location. This will help the web researcher to find the relevant weather information for that area.", 'next': 'personal_info_agent'}
# {'explanation': "Now that we have the user's location, the web researcher can look up the weather forecast for Lviv, Ukraine.", 'next': 'web_researcher'}
# {'explanation': "The user's request for weather information has been fulfilled with a detailed forecast for Lviv, Ukraine. No further actions are needed unless the user has additional questions.", 'next': 'FINISH'}

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles

display(
    Image(
        main_wf.mac.graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
